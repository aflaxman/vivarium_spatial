# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
# !date
# Out:
# Sat Dec  7 22:06:31 PST 2024

# %%
fname = '/home/abie/vivarium_results/model_spec/2024_12_07_22_07_00/results/collision_counts.parquet'
df = pd.read_parquet(fname).set_index('whimsy_decile')
df
# Out:
#                value
# whimsy_decile
# decile_1        40.0
# decile_2        17.0
# decile_3        53.0
# decile_4         0.0
# decile_5        48.0
# decile_6         0.0
# decile_7        53.0
# decile_8         0.0
# decile_9        48.0
# decile_10       23.0

# %%
df.sum()
# Out:
# value    282.0
# dtype: float64

# %%
16*15/2
# Out:
# 120.0

# %%
df.plot(kind='bar')
# Out:
# <Axes: xlabel='whimsy_decile'>
